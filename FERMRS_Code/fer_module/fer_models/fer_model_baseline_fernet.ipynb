# %% [markdown]
# # FER Model Creation

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import seaborn as sns
sns.set_theme(style="whitegrid")

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import *

# %% [markdown]
# ## Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/fer.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    emotion                                             pixels
# 0        1  204 206 200 104 71 77 112 170 193 204 218 223 ...
# 1        1  19 21 27 28 33 29 41 37 24 31 42 45 48 62 63 7...
# 2        1  223 245 233 243 243 243 244 244 248 245 218 21...
# 3        1  119 30 120 166 119 101 108 91 51 58 68 82 100 ...
# 4        1  76 93 103 96 99 103 103 120 134 138 149 150 14...

# %%
df.shape
# Out:
# (17978, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17978 entries, 0 to 17977
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   emotion  17978 non-null  int64
#  1   pixels   17978 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 281.0+ KB

# %%
df.emotion.value_counts()
# Out:
# 1    8989
# 0    8989
# Name: emotion, dtype: int64

# %% [markdown]
# ## Pre-processing

# %%
img_array = df.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))
img_array = np.stack(img_array, axis=0)

# %%
img_array.shape
# Out:
# (17978, 48, 48, 1)

# %%
img_labels = df.emotion.values

# %%
img_labels.shape
# Out:
# (17978,)

# %% [markdown]
# ## Splitting the data into training and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(img_array, 
                                                    img_labels,
                                                    test_size=0.1, 
                                                    shuffle=True,
                                                    random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  test_size=0.1, 
                                                  random_state=42)

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
print("\n")
print("X_val shape: {}".format(X_val.shape))
print("y val shape: {}".format(y_val.shape))
print("\n")
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_train shape: (14562, 48, 48, 1)
# y_train shape: (14562,)
#
#
# X_val shape: (1618, 48, 48, 1)
# y val shape: (1618,)
#
#
# X_test shape: (1798, 48, 48, 1)
# y_test shape: (1798,)

# %%
print(np.round(((X_train.shape[0]) / (img_array.shape[0]))*100), "% of Train set")
print(np.round(((X_val.shape[0]) / (img_array.shape[0]))*100), "% of Validation set")
print(np.round(((X_test.shape[0]) / (img_array.shape[0]))*100), "% of Test set")
# Out:
# 81.0 % of Train set
# 9.0 % of Validation set
# 10.0 % of Test set

# %% [markdown]
# ## Image Properties

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]

# %%
print("The following are the image properties :")
print("   Width =", img_width)
print("   Height =", img_height)
print("   Depth =", img_depth)
# Out:
# The following are the image properties :
#    Width = 48
#    Height = 48
#    Depth = 1

# %% [markdown]
# ## Normalization

# %%
X_train = X_train / 255.

X_val = X_val / 255.

X_test = X_test / 255.

# %% [markdown]
# ## Model

# %%
def model():

    net = Sequential(name='DCNN')

    net.add(
        Conv2D(
            filters=32,
            kernel_size=(5,5),
            input_shape=(img_width, img_height, img_depth),
            activation='relu',
            padding='same',
            name='conv2d_1'))
    
    net.add(BatchNormalization(name='batchnorm_1'))
    
    net.add(
        Conv2D(
            filters=32,
            kernel_size=(5,5),
            activation='relu',
            padding='same',
            name='conv2d_2'))
    
    net.add(BatchNormalization(name='batchnorm_2'))
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    net.add(Dropout(0.4, name='dropout_1'))

    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_3'))

    net.add(BatchNormalization(name='batchnorm_3'))
    
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_4'))
    
    net.add(BatchNormalization(name='batchnorm_4'))
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    net.add(Dropout(0.4, name='dropout_2'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_5'))
    
    net.add(BatchNormalization(name='batchnorm_5'))
    
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_6'))
    
    net.add(BatchNormalization(name='batchnorm_6'))
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
    net.add(Dropout(0.5, name='dropout_3'))

    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_7'))
    
    net.add(BatchNormalization(name='batchnorm_7'))
    
    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='relu',
            padding='same',
            name='conv2d_8'))
    
    net.add(BatchNormalization(name='batchnorm_8'))
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_4'))
    net.add(Dropout(0.5, name='dropout_4'))

    net.add(Flatten(name='flatten'))
        
    net.add(
        Dense(
            512,
            activation='relu',
            name='dense_1'))
    
    net.add(BatchNormalization(name='batchnorm_9'))
    net.add(Dropout(0.6, name='dropout_5'))
    
    net.add(
        Dense(
            128,
            activation='relu',
            name='dense_2'))
    
    net.add(BatchNormalization(name='batchnorm_10'))
    net.add(Dropout(0.6, name='dropout_6'))
    

    net.add(
        Dense(
            1,
            activation='sigmoid',
            name='out_layer'))
    
    net.compile(
        loss='binary_crossentropy',
        optimizer='adam',
        metrics=['accuracy'])
    
    net.summary()
    
    return net

# %% [markdown]
# ## Callbacks

# %%
checkpoint = ModelCheckpoint(filepath='fernet.h5',
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

callbacks = [checkpoint]

# %% [markdown]
# ## Model Summary

# %%
fernet = model()
# Out:
# Model: "DCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        832
#
#  batchnorm_1 (BatchNormaliza  (None, 48, 48, 32)       128
#  tion)
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 32)        25632
#
#  batchnorm_2 (BatchNormaliza  (None, 48, 48, 32)       128
#  tion)
#
#  maxpool2d_1 (MaxPooling2D)  (None, 24, 24, 32)        0
#
#  dropout_1 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batchnorm_3 (BatchNormaliza  (None, 24, 24, 64)       256
#  tion)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        36928
#
#  batchnorm_4 (BatchNormaliza  (None, 24, 24, 64)       256
#  tion)
#
#  maxpool2d_2 (MaxPooling2D)  (None, 12, 12, 64)        0
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batchnorm_5 (BatchNormaliza  (None, 12, 12, 128)      512
#  tion)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 128)       147584
#
#  batchnorm_6 (BatchNormaliza  (None, 12, 12, 128)      512
#  tion)
#
#  maxpool2d_3 (MaxPooling2D)  (None, 6, 6, 128)         0
#
#  dropout_3 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)         295168
#
#  batchnorm_7 (BatchNormaliza  (None, 6, 6, 256)        1024
#  tion)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batchnorm_8 (BatchNormaliza  (None, 6, 6, 256)        1024
#  tion)
#
#  maxpool2d_4 (MaxPooling2D)  (None, 3, 3, 256)         0
#
#  dropout_4 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense_1 (Dense)             (None, 512)               1180160
#
#  batchnorm_9 (BatchNormaliza  (None, 512)              2048
#  tion)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  batchnorm_10 (BatchNormaliz  (None, 128)              512
#  ation)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  out_layer (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 2,440,929
# Trainable params: 2,437,729
# Non-trainable params: 3,200
# _________________________________________________________________

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (8.4.0)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.16-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.0/992.0 KB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.9/dist-packages (from visualkeras) (1.22.4)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import visualkeras
from tensorflow.keras import layers
from collections import defaultdict

color_map = defaultdict(dict)
color_map[layers.Conv2D]['fill'] = '#ffffff'
color_map[layers.BatchNormalization]['fill'] = '#dedcd9'
color_map[layers.MaxPooling2D]['fill'] = '#b0afac'
color_map[layers.Dropout]['fill'] = '#82817f'
color_map[layers.Dense]['fill'] = '#030302'
color_map[layers.Flatten]['fill'] = '#575552'

visualkeras.layered_view(fernet, legend=True, color_map=color_map, draw_volume=True, draw_funnel=False)
# Out:
# <PIL.Image.Image image mode=RGBA size=1343x292 at 0x7FA2922DDB80>

# %% [markdown]
# ## Model Training

# %%
batch_size = 64
epochs = 30
steps_per_epoch = len(X_train) / batch_size
validation_steps = len(X_val) / batch_size

# %%
history = fernet.fit(X_train, y_train,
                     validation_data=(X_val, y_val),
                     steps_per_epoch=steps_per_epoch,
                     epochs=epochs,
                     callbacks=callbacks,
                     validation_steps=validation_steps)
# Out:
# Epoch 1/30
# 228/227 [==============================] - ETA: 0s - loss: 0.8909 - accuracy: 0.5464
# Epoch 1: val_loss improved from inf to 0.76672, saving model to fernet.h5
# 227/227 [==============================] - 36s 38ms/step - loss: 0.8909 - accuracy: 0.5464 - val_loss: 0.7667 - val_accuracy: 0.4895
# Epoch 2/30
# 228/227 [==============================] - ETA: 0s - loss: 0.6996 - accuracy: 0.6059
# Epoch 2: val_loss improved from 0.76672 to 0.62505, saving model to fernet.h5
# 227/227 [==============================] - 9s 39ms/step - loss: 0.6996 - accuracy: 0.6059 - val_loss: 0.6251 - val_accuracy: 0.6533
# Epoch 3/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.6057 - accuracy: 0.6824
# Epoch 3: val_loss did not improve from 0.62505
# 227/227 [==============================] - 9s 38ms/step - loss: 0.6060 - accuracy: 0.6823 - val_loss: 0.6447 - val_accuracy: 0.6842
# Epoch 4/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.5250 - accuracy: 0.7380
# Epoch 4: val_loss did not improve from 0.62505
# 227/227 [==============================] - 7s 30ms/step - loss: 0.5248 - accuracy: 0.7383 - val_loss: 0.7211 - val_accuracy: 0.6551
# Epoch 5/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.4617 - accuracy: 0.7870
# Epoch 5: val_loss improved from 0.62505 to 0.51916, saving model to fernet.h5
# 227/227 [==============================] - 7s 33ms/step - loss: 0.4618 - accuracy: 0.7868 - val_loss: 0.5192 - val_accuracy: 0.7373
# Epoch 6/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.4054 - accuracy: 0.8146
# Epoch 6: val_loss improved from 0.51916 to 0.40523, saving model to fernet.h5
# 227/227 [==============================] - 7s 31ms/step - loss: 0.4055 - accuracy: 0.8144 - val_loss: 0.4052 - val_accuracy: 0.8319
# Epoch 7/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.3605 - accuracy: 0.8368
# Epoch 7: val_loss improved from 0.40523 to 0.30595, saving model to fernet.h5
# 227/227 [==============================] - 7s 33ms/step - loss: 0.3610 - accuracy: 0.8366 - val_loss: 0.3060 - val_accuracy: 0.8708
# Epoch 8/30
# 228/227 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8585
# Epoch 8: val_loss improved from 0.30595 to 0.27354, saving model to fernet.h5
# 227/227 [==============================] - 9s 37ms/step - loss: 0.3265 - accuracy: 0.8585 - val_loss: 0.2735 - val_accuracy: 0.8857
# Epoch 9/30
# 228/227 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8754
# Epoch 9: val_loss improved from 0.27354 to 0.23348, saving model to fernet.h5
# 227/227 [==============================] - 9s 41ms/step - loss: 0.2987 - accuracy: 0.8754 - val_loss: 0.2335 - val_accuracy: 0.8999
# Epoch 10/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.2737 - accuracy: 0.8848
# Epoch 10: val_loss improved from 0.23348 to 0.23105, saving model to fernet.h5
# 227/227 [==============================] - 8s 33ms/step - loss: 0.2737 - accuracy: 0.8848 - val_loss: 0.2310 - val_accuracy: 0.9054
# Epoch 11/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.2606 - accuracy: 0.8926
# Epoch 11: val_loss did not improve from 0.23105
# 227/227 [==============================] - 7s 31ms/step - loss: 0.2604 - accuracy: 0.8927 - val_loss: 0.2397 - val_accuracy: 0.8986
# Epoch 12/30
# 226/227 [============================>.] - ETA: 0s - loss: 0.2441 - accuracy: 0.9051
# Epoch 12: val_loss did not improve from 0.23105
# 227/227 [==============================] - 8s 35ms/step - loss: 0.2443 - accuracy: 0.9048 - val_loss: 0.2370 - val_accuracy: 0.9067
# Epoch 13/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.2338 - accuracy: 0.9065
# Epoch 13: val_loss did not improve from 0.23105
# 227/227 [==============================] - 7s 31ms/step - loss: 0.2335 - accuracy: 0.9065 - val_loss: 0.2529 - val_accuracy: 0.8943
# Epoch 14/30
# 228/227 [==============================] - ETA: 0s - loss: 0.2147 - accuracy: 0.9148
# Epoch 14: val_loss improved from 0.23105 to 0.21511, saving model to fernet.h5
# 227/227 [==============================] - 9s 39ms/step - loss: 0.2147 - accuracy: 0.9148 - val_loss: 0.2151 - val_accuracy: 0.9141
# Epoch 15/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9192
# Epoch 15: val_loss improved from 0.21511 to 0.19097, saving model to fernet.h5
# 227/227 [==============================] - 7s 32ms/step - loss: 0.2036 - accuracy: 0.9191 - val_loss: 0.1910 - val_accuracy: 0.9190
# Epoch 16/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9246
# Epoch 16: val_loss did not improve from 0.19097
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1930 - accuracy: 0.9247 - val_loss: 0.2134 - val_accuracy: 0.9215
# Epoch 17/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1804 - accuracy: 0.9305
# Epoch 17: val_loss did not improve from 0.19097
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1802 - accuracy: 0.9306 - val_loss: 0.2002 - val_accuracy: 0.9283
# Epoch 18/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1729 - accuracy: 0.9351
# Epoch 18: val_loss improved from 0.19097 to 0.17276, saving model to fernet.h5
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1738 - accuracy: 0.9348 - val_loss: 0.1728 - val_accuracy: 0.9370
# Epoch 19/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.9384
# Epoch 19: val_loss improved from 0.17276 to 0.15716, saving model to fernet.h5
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1647 - accuracy: 0.9385 - val_loss: 0.1572 - val_accuracy: 0.9431
# Epoch 20/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1567 - accuracy: 0.9404
# Epoch 20: val_loss did not improve from 0.15716
# 227/227 [==============================] - 7s 31ms/step - loss: 0.1566 - accuracy: 0.9403 - val_loss: 0.1823 - val_accuracy: 0.9320
# Epoch 21/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9443
# Epoch 21: val_loss did not improve from 0.15716
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1488 - accuracy: 0.9444 - val_loss: 0.1652 - val_accuracy: 0.9339
# Epoch 22/30
# 226/227 [============================>.] - ETA: 0s - loss: 0.1399 - accuracy: 0.9488
# Epoch 22: val_loss did not improve from 0.15716
# 227/227 [==============================] - 7s 33ms/step - loss: 0.1397 - accuracy: 0.9488 - val_loss: 0.2931 - val_accuracy: 0.8826
# Epoch 23/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1362 - accuracy: 0.9482
# Epoch 23: val_loss did not improve from 0.15716
# 227/227 [==============================] - 7s 31ms/step - loss: 0.1364 - accuracy: 0.9479 - val_loss: 0.1829 - val_accuracy: 0.9246
# Epoch 24/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9516
# Epoch 24: val_loss did not improve from 0.15716
# 227/227 [==============================] - 7s 30ms/step - loss: 0.1311 - accuracy: 0.9517 - val_loss: 0.1597 - val_accuracy: 0.9376
# Epoch 25/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9524
# Epoch 25: val_loss improved from 0.15716 to 0.14267, saving model to fernet.h5
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1297 - accuracy: 0.9523 - val_loss: 0.1427 - val_accuracy: 0.9493
# Epoch 26/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9566
# Epoch 26: val_loss did not improve from 0.14267
# 227/227 [==============================] - 7s 31ms/step - loss: 0.1143 - accuracy: 0.9565 - val_loss: 0.2027 - val_accuracy: 0.9314
# Epoch 27/30
# 228/227 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9578
# Epoch 27: val_loss did not improve from 0.14267
# 227/227 [==============================] - 8s 35ms/step - loss: 0.1147 - accuracy: 0.9578 - val_loss: 0.2085 - val_accuracy: 0.9252
# Epoch 28/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9565
# Epoch 28: val_loss improved from 0.14267 to 0.14109, saving model to fernet.h5
# 227/227 [==============================] - 7s 32ms/step - loss: 0.1144 - accuracy: 0.9564 - val_loss: 0.1411 - val_accuracy: 0.9499
# Epoch 29/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9609
# Epoch 29: val_loss improved from 0.14109 to 0.13728, saving model to fernet.h5
# 227/227 [==============================] - 7s 31ms/step - loss: 0.1017 - accuracy: 0.9609 - val_loss: 0.1373 - val_accuracy: 0.9543
# Epoch 30/30
# 227/227 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9646
# Epoch 30: val_loss did not improve from 0.13728
# 227/227 [==============================] - 7s 32ms/step - loss: 0.0996 - accuracy: 0.9647 - val_loss: 0.1727 - val_accuracy: 0.9438

# %% [markdown]
# ## Result Plots

# %%
def plot_curves(history):

    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]

    epochs = range(len(history.history["loss"]))

    plt.figure(figsize=(15,5))

    #plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label = "train_loss")
    plt.plot(epochs, val_loss, label = "val_loss")
    plt.title("Model Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    #plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label = "train_accuracy")
    plt.plot(epochs, val_accuracy, label = "val_accuracy")
    plt.title("Model Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")   
    plt.legend()
    
    plt.tight_layout()

# %%
plot_curves(history)

# %%
df_accu = pd.DataFrame({'train': history.history['accuracy'], 'val': history.history['val_accuracy']})
df_loss = pd.DataFrame({'train': history.history['loss'], 'val': history.history['val_loss']})

fig = plt.figure(0, (14, 4))
ax = plt.subplot(1, 2, 1)
sns.violinplot(x="variable", y="value", data=pd.melt(df_accu), showfliers=False)
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.violinplot(x="variable", y="value", data=pd.melt(df_loss), showfliers=False)
plt.title('Loss')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Model Evaluation

# %%
train_loss, train_accuracy = fernet.evaluate(X_train, y_train)
print("Train loss = {:.2f}".format(train_loss))
print("Train accuracy = {:.2f}%".format(train_accuracy*100))
# Out:
# 456/456 [==============================] - 3s 6ms/step - loss: 0.0389 - accuracy: 0.9870
# Train loss = 0.04
# Train accuracy = 98.70%

# %%
val_loss, val_accuracy = fernet.evaluate(X_val, y_val)
print("Validation loss = {:.2f}".format(val_loss))
print("Validation accuracy = {:.2f}%".format(val_accuracy*100))
# Out:
# 51/51 [==============================] - 0s 7ms/step - loss: 0.1727 - accuracy: 0.9438
# Validation loss = 0.17
# Validation accuracy = 94.38%

# %%
val_pred = fernet.predict(X_val)
y_val_pred = np.where(val_pred > 0.5, 1, 0)
# Out:
# 51/51 [==============================] - 0s 5ms/step

# %%
print('Baseline Model Confusion Matrix')

cm = tf.math.confusion_matrix(y_val, y_val_pred, num_classes=2, dtype=tf.dtypes.int32)

sns.heatmap(cm, annot=True, fmt="d")

plt.title('Baseline Model Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Baseline Model Confusion Matrix

# %%
fpr, tpr, _ = roc_curve(y_val, y_val_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Baseline Model ROC curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### New data for Predictions

# %%
pred = fernet.predict(X_test)
y_pred = np.where(pred > 0.5, 1, 0)
# Out:
# 57/57 [==============================] - 0s 8ms/step

# %%
print('Classification Report for Test set:')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report for Test set:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.93       901
#            1       0.90      0.98      0.94       897
#
#     accuracy                           0.94      1798
#    macro avg       0.94      0.94      0.94      1798
# weighted avg       0.94      0.94      0.94      1798

# %%
acc = accuracy_score(y_test, y_pred)

prec = precision_score(y_test, y_pred)

rec = recall_score(y_test, y_pred)

print(f"Accuracy: {acc:.2f} \nPrecision: {prec:.2f} \nRecall: {rec:.2f}")
# Out:
# Accuracy: 0.94
# Precision: 0.90
# Recall: 0.98

# %%
Emotion_Classes = {0 : 'happy', 1 : 'sad'}

# %%
np.random.seed(2)
random_happy_imgs = np.random.choice(np.where(y_test[:]==0)[0], size=9)
random_sad_imgs = np.random.choice(np.where(y_test[:]==1)[0], size=9)

fig = plt.figure(1, (20, 5))

for i, (happyidx, sadidx) in enumerate(zip(random_happy_imgs, random_sad_imgs)):

        ax = plt.subplot(2, 9, i+1)
        hap_sample_img = X_test[happyidx,:,:,0]
        hap_img_resized = hap_sample_img.reshape(1,48,48,1)
        hap_pred = fernet.predict(hap_img_resized)
        y_pred_hap = np.where(hap_pred > 0.5, 1, 0)
        
        if (y_pred_hap[0]) == (y_test[happyidx]):
            color_hap = "green"
        else:
            color_hap = "red"

        hap_img = hap_img_resized.reshape(48,48)
        ax.imshow(hap_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"true:happy, predict:{Emotion_Classes[y_pred_hap[0][0]]}", color=color_hap)

        ax = plt.subplot(2, 9, i+10)
        sad_sample_img = X_test[sadidx,:,:,0]
        sad_img_resized = sad_sample_img.reshape(1,48,48,1)
        sad_pred = fernet.predict(sad_img_resized)
        y_pred_sad = np.where(sad_pred > 0.5, 1, 0)

        if (y_pred_sad[0]) == (y_test[sadidx]):
            color_sad = "green"
        else:
            color_sad = "red"

        sad_img = sad_img_resized.reshape(48,48)
        ax.imshow(sad_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"true:sad, predict:{Emotion_Classes[y_pred_sad[0][0]]}", color=color_sad)

        plt.tight_layout()
# Out:
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# `Saved the fernet model weights`
